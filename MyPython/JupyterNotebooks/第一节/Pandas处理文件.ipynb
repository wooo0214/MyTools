# %%
## 安装命令  pip install pandas
# 如果你使用的是anaconda 环境  pandas是自带的，就不用安装了

# %%
# 导入pandas包
# as pd就是给pandas起一个别名，后续使用的时候会比较方便
import pandas as pd
# shift + 回车  运行本代码块

# %%
## Pandas是专门用来做数据处理的库
# Pandas包含两种数据类型
# Series
# DataFrame

# %%
# pandas读取文件 excel格式
sheet1_data = pd.read_excel("./数据分析测试题.xlsx")

sheet1_data
# Out:
#       专业   题型  难度            对应知识点  \
# 0   数据分析   单选   1           数据分析概念
# 1   数据分析  判断题   1           数据分析概念
# 2   数据分析   单选   1           数据分析概念
# 3   数据分析  填空题   2           数据分析概念
# 4   数据分析  填空题   2           数据分析概念
# 5   数据分析   单选   1           数据分析概念
# 6   数据分析   多选   1           数据分析概念
# 7   数据分析   多选   2           数据分析概念
# 8   数据分析  填空题   3           数据分析概念
# 9   数据分析  填空题   3           数据分析概念
# 10  数据分析  填空题   3           数据分析概念
# 11  数据分析  填空题   3           数据分析概念
# 12  数据分析   单选   2           数据分析概念
# 13  数据分析   单选   3           数据分析概念
# 14  数据分析   单选   3           数据分析概念
# 15  数据分析   多选   1           数据分析概念
# 16  数据分析  判断题   1           数据分析概念
# 17  数据分析  判断题   1           数据分析概念
# 18  数据分析  单选题   2           数据分析概念
# 19  数据分析  单选题   2           数据分析概念
# 20  数据分析  单选题   2           数据分析概念
# 21  数据分析  填空题   3           数据分析概念
# 22  数据分析  填空题   3           数据分析概念
# 23  数据分析  单选题   2           数据分析概念
# 24  数据分析  单选题   2           数据分析概念
# ...

# %%
# 绝对路径与相对路径
d =pd.read_excel("/Users/zjy/workspace/greedy_ai/贪心/4、课程规划/8、数据分析课程/course_code/第一节/数据分析测试题.xlsx")
d
# Out:
#       专业   题型  难度            对应知识点  \
# 0   数据分析   单选   1           数据分析概念
# 1   数据分析  判断题   1           数据分析概念
# 2   数据分析   单选   1           数据分析概念
# 3   数据分析  填空题   2           数据分析概念
# 4   数据分析  填空题   2           数据分析概念
# 5   数据分析   单选   1           数据分析概念
# 6   数据分析   多选   1           数据分析概念
# 7   数据分析   多选   2           数据分析概念
# 8   数据分析  填空题   3           数据分析概念
# 9   数据分析  填空题   3           数据分析概念
# 10  数据分析  填空题   3           数据分析概念
# 11  数据分析  填空题   3           数据分析概念
# 12  数据分析   单选   2           数据分析概念
# 13  数据分析   单选   3           数据分析概念
# 14  数据分析   单选   3           数据分析概念
# 15  数据分析   多选   1           数据分析概念
# 16  数据分析  判断题   1           数据分析概念
# 17  数据分析  判断题   1           数据分析概念
# 18  数据分析  单选题   2           数据分析概念
# 19  数据分析  单选题   2           数据分析概念
# 20  数据分析  单选题   2           数据分析概念
# 21  数据分析  填空题   3           数据分析概念
# 22  数据分析  填空题   3           数据分析概念
# 23  数据分析  单选题   2           数据分析概念
# 24  数据分析  单选题   2           数据分析概念
# ...

# %%
a = pd.read_excel("../1.xlsx")
a
# Out:
#       专业   题型  难度            对应知识点  \
# 0   数据分析   单选   1           数据分析概念
# 1   数据分析  判断题   1           数据分析概念
# 2   数据分析   单选   1           数据分析概念
# 3   数据分析  填空题   2           数据分析概念
# 4   数据分析  填空题   2           数据分析概念
# 5   数据分析   单选   1           数据分析概念
# 6   数据分析   多选   1           数据分析概念
# 7   数据分析   多选   2           数据分析概念
# 8   数据分析  填空题   3           数据分析概念
# 9   数据分析  填空题   3           数据分析概念
# 10  数据分析  填空题   3           数据分析概念
# 11  数据分析  填空题   3           数据分析概念
# 12  数据分析   单选   2           数据分析概念
# 13  数据分析   单选   3           数据分析概念
# 14  数据分析   单选   3           数据分析概念
# 15  数据分析   多选   1           数据分析概念
# 16  数据分析  判断题   1           数据分析概念
# 17  数据分析  判断题   1           数据分析概念
# 18  数据分析  单选题   2           数据分析概念
# 19  数据分析  单选题   2           数据分析概念
# 20  数据分析  单选题   2           数据分析概念
# 21  数据分析  填空题   3           数据分析概念
# 22  数据分析  填空题   3           数据分析概念
# 23  数据分析  单选题   2           数据分析概念
# 24  数据分析  单选题   2           数据分析概念
# ...

# %%
b = pd.read_excel("../a/2.xlsx")
b
# Out:
#       专业   题型  难度            对应知识点  \
# 0   数据分析   单选   1           数据分析概念
# 1   数据分析  判断题   1           数据分析概念
# 2   数据分析   单选   1           数据分析概念
# 3   数据分析  填空题   2           数据分析概念
# 4   数据分析  填空题   2           数据分析概念
# 5   数据分析   单选   1           数据分析概念
# 6   数据分析   多选   1           数据分析概念
# 7   数据分析   多选   2           数据分析概念
# 8   数据分析  填空题   3           数据分析概念
# 9   数据分析  填空题   3           数据分析概念
# 10  数据分析  填空题   3           数据分析概念
# 11  数据分析  填空题   3           数据分析概念
# 12  数据分析   单选   2           数据分析概念
# 13  数据分析   单选   3           数据分析概念
# 14  数据分析   单选   3           数据分析概念
# 15  数据分析   多选   1           数据分析概念
# 16  数据分析  判断题   1           数据分析概念
# 17  数据分析  判断题   1           数据分析概念
# 18  数据分析  单选题   2           数据分析概念
# 19  数据分析  单选题   2           数据分析概念
# 20  数据分析  单选题   2           数据分析概念
# 21  数据分析  填空题   3           数据分析概念
# 22  数据分析  填空题   3           数据分析概念
# 23  数据分析  单选题   2           数据分析概念
# 24  数据分析  单选题   2           数据分析概念
# ...

# %%
sheet1_data = pd.read_excel("./数据分析测试题.xlsx")
sheet1_data
# Out:
#       专业   题型  难度            对应知识点  \
# 0   数据分析   单选   1           数据分析概念
# 1   数据分析  判断题   1           数据分析概念
# 2   数据分析   单选   1           数据分析概念
# 3   数据分析  填空题   2           数据分析概念
# 4   数据分析  填空题   2           数据分析概念
# 5   数据分析   单选   1           数据分析概念
# 6   数据分析   多选   1           数据分析概念
# 7   数据分析   多选   2           数据分析概念
# 8   数据分析  填空题   3           数据分析概念
# 9   数据分析  填空题   3           数据分析概念
# 10  数据分析  填空题   3           数据分析概念
# 11  数据分析  填空题   3           数据分析概念
# 12  数据分析   单选   2           数据分析概念
# 13  数据分析   单选   3           数据分析概念
# 14  数据分析   单选   3           数据分析概念
# 15  数据分析   多选   1           数据分析概念
# 16  数据分析  判断题   1           数据分析概念
# 17  数据分析  判断题   1           数据分析概念
# 18  数据分析  单选题   2           数据分析概念
# 19  数据分析  单选题   2           数据分析概念
# 20  数据分析  单选题   2           数据分析概念
# 21  数据分析  填空题   3           数据分析概念
# 22  数据分析  填空题   3           数据分析概念
# 23  数据分析  单选题   2           数据分析概念
# 24  数据分析  单选题   2           数据分析概念
# ...

# %%
sheet2_data = pd.read_excel("./数据分析测试题.xlsx",sheet_name="第一阶段第二套")
sheet2_data
# Out:
#       专业   题型  难度            对应知识点  \
# 0   数据分析  填空题   1           数据分析概念
# 1   数据分析  填空题   2           数据分析概念
# 2   数据分析   多选   2           数据分析概念
# 3   数据分析  判断题   3           数据分析概念
# 4   数据分析   多选   3           数据分析概念
# 5   数据分析  判断题   1           数据分析概念
# 6   数据分析  判断题   3           数据分析概念
# 7   数据分析  填空题   3           数据分析概念
# 8   数据分析   单选   3           数据分析概念
# 9   数据分析  判断题   1           数据分析概念
# 10  数据分析  填空题   2           数据分析概念
# 11  数据分析  填空题   1           数据分析概念
# 12  数据分析  填空题   3           数据分析概念
# 13  数据分析   多选   1           数据分析概念
# 14  数据分析  判断题   1           数据分析概念
# 15  数据分析  填空题   2           数据分析概念
# 16  数据分析  填空题   3           数据分析概念
# 17  数据分析  多选题   2           数据分析概念
# 18  数据分析  填空题   3           数据分析概念
# 19  数据分析  填空题   3           数据分析概念
# 20  数据分析  填空题   2           数据分析概念
# 21  数据分析   多选   1           数据分析概念
# 22  数据分析   多选   1           数据分析概念
# 23  数据分析  填空题   3           数据分析概念
# 24  数据分析  判断题   3           数据分析概念
# ...

# %%
type(sheet2_data)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = pd.DataFrame({"aa":[1,2,3],
                    "bbb":[4,5,6]})
df1
# Out:
#    aa  bbb
# 0   1    4
# 1   2    5
# 2   3    6

# %%
df2 = pd.DataFrame({"aa":[1,2,3],
                    "bbb":[4,5,6]},index=[101,102,103])
df2
# Out:
#      aa  bbb
# 101   1    4
# 102   2    5
# 103   3    6

# %%
# 查看形状
sheet1_data.shape
# Out:
# (50, 7)

# %%
type(sheet1_data.shape)
# Out:
# tuple

# %%
# 使用dtypes来查看DataFrame数据类型中列的数据类型
sheet1_data.dtypes
# object --> 字符串
#  int64 --> int
# float
# Out:
# 专业         object
# 题型         object
# 难度          int64
# 对应知识点      object
# 题干         object
# 选项（如果有）    object
# 答案         object
# dtype: object

# %%
# 使用index属性可以查看到行索引
sheet1_data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
## 如果我想要查看列索引怎么办？
sheet1_data.columns
# Out:
# Index(['专业', '题型', '难度', '对应知识点', '题干', '选项（如果有）', '答案'], dtype='object')

# %%
sheet1_data.values
# Out:
# array([['数据分析', '单选', 1, '数据分析概念', '关于电商网站数据抓取的方式不包括',
#         'A.第三方工具抓取\nB.爬虫程序抓取\nC.数据库提取\nD.人工抓取', 'C'],
#        ['数据分析', '判断题', 1, '数据分析概念', '以下软件/语言是否都属于数据分析软件/语言',
#         'A.SPSS\nB.Python\nC.Excel\nD.R', '是'],
#        ['数据分析', '单选', 1, '数据分析概念', '在电商中针对仓储备货场景一般采用什么分析方式',
#         'A.线性回归\nB.数学仿真\nC.逻辑回归\nD.分类', 'B'],
#        ['数据分析', '填空题', 2, '数据分析概念', '数据分析的四大步骤是什么', nan,
#         '数据抓取→数据清洗→数据分析→业务决策'],
#        ['数据分析', '填空题', 2, '数据分析概念', '优秀数据分析师的三个特点是什么', nan,
#         '业务理解、工具使用、沟通表达'],
#        ['数据分析', '单选', 1, '数据分析概念', 'Excel相比于Python的优势是什么',
#         'A.处理大数据分析时效率较高\nB.分析工具学习入门门槛低\nC.数据可视化个性度高', 'B'],
#        ['数据分析', '多选', 1, '数据分析概念', 'Excel适用于哪些类似的公司进行数据分析',
#         'A.电商入驻商\nB.电商平台\nC.线下零售商\nD.电商服务商', 'A、C'],
#        ['数据分析', '多选', 2, '数据分析概念', '数据分析报告对一线业务的帮助包含',
#         'A.广告投放优化\nB.渠道管理优化\nC.人员管理优化\nD.用户管理优化', 'A、B、C、D'],
#        ['数据分析', '填空题', 3, '数据分析概念', '数据分析报告的要求包含哪些', nan,
#         'A.简洁性\nB.概括性\nC.方向性'],
# ...

# %%
type(sheet1_data.values)
# Out:
# numpy.ndarray

# %%
sheet1_data.size 

# 50 * 7 = 350
# Out:
# 350

# %%
sheet1_data
# Out:
#       专业   题型  难度            对应知识点  \
# 0   数据分析   单选   1           数据分析概念
# 1   数据分析  判断题   1           数据分析概念
# 2   数据分析   单选   1           数据分析概念
# 3   数据分析  填空题   2           数据分析概念
# 4   数据分析  填空题   2           数据分析概念
# 5   数据分析   单选   1           数据分析概念
# 6   数据分析   多选   1           数据分析概念
# 7   数据分析   多选   2           数据分析概念
# 8   数据分析  填空题   3           数据分析概念
# 9   数据分析  填空题   3           数据分析概念
# 10  数据分析  填空题   3           数据分析概念
# 11  数据分析  填空题   3           数据分析概念
# 12  数据分析   单选   2           数据分析概念
# 13  数据分析   单选   3           数据分析概念
# 14  数据分析   单选   3           数据分析概念
# 15  数据分析   多选   1           数据分析概念
# 16  数据分析  判断题   1           数据分析概念
# 17  数据分析  判断题   1           数据分析概念
# 18  数据分析  单选题   2           数据分析概念
# 19  数据分析  单选题   2           数据分析概念
# 20  数据分析  单选题   2           数据分析概念
# 21  数据分析  填空题   3           数据分析概念
# 22  数据分析  填空题   3           数据分析概念
# 23  数据分析  单选题   2           数据分析概念
# 24  数据分析  单选题   2           数据分析概念
# ...

# %%
sheet1_data.head()
# Out:
#      专业   题型  难度   对应知识点                      题干  \
# 0  数据分析   单选   1  数据分析概念        关于电商网站数据抓取的方式不包括
# 1  数据分析  判断题   1  数据分析概念   以下软件/语言是否都属于数据分析软件/语言
# 2  数据分析   单选   1  数据分析概念  在电商中针对仓储备货场景一般采用什么分析方式
# 3  数据分析  填空题   2  数据分析概念            数据分析的四大步骤是什么
# 4  数据分析  填空题   2  数据分析概念         优秀数据分析师的三个特点是什么
#
#                                 选项（如果有）                   答案
# 0  A.第三方工具抓取\nB.爬虫程序抓取\nC.数据库提取\nD.人工抓取                    C
# 1        A.SPSS\nB.Python\nC.Excel\nD.R                    是
# 2          A.线性回归\nB.数学仿真\nC.逻辑回归\nD.分类                    B
# 3                                   NaN  数据抓取→数据清洗→数据分析→业务决策
# 4                                   NaN       业务理解、工具使用、沟通表达

# %%
sheet1_data.head(10)
# Out:
#      专业   题型  难度   对应知识点                      题干  \
# 0  数据分析   单选   1  数据分析概念        关于电商网站数据抓取的方式不包括
# 1  数据分析  判断题   1  数据分析概念   以下软件/语言是否都属于数据分析软件/语言
# 2  数据分析   单选   1  数据分析概念  在电商中针对仓储备货场景一般采用什么分析方式
# 3  数据分析  填空题   2  数据分析概念            数据分析的四大步骤是什么
# 4  数据分析  填空题   2  数据分析概念         优秀数据分析师的三个特点是什么
# 5  数据分析   单选   1  数据分析概念    Excel相比于Python的优势是什么
# 6  数据分析   多选   1  数据分析概念   Excel适用于哪些类似的公司进行数据分析
# 7  数据分析   多选   2  数据分析概念        数据分析报告对一线业务的帮助包含
# 8  数据分析  填空题   3  数据分析概念           数据分析报告的要求包含哪些
# 9  数据分析  填空题   3  数据分析概念       互联网数据分析师需要对什么指标负责
#
#                                       选项（如果有）                   答案
# 0        A.第三方工具抓取\nB.爬虫程序抓取\nC.数据库提取\nD.人工抓取                    C
# 1              A.SPSS\nB.Python\nC.Excel\nD.R                    是
# 2                A.线性回归\nB.数学仿真\nC.逻辑回归\nD.分类                    B
# 3                                         NaN  数据抓取→数据清洗→数据分析→业务决策
# 4                                         NaN       业务理解、工具使用、沟通表达
# ...

# %%
## 查看部分列的数据
sheet1_data["题型"].head()
# Out:
# 0     单选
# 1    判断题
# 2     单选
# 3    填空题
# 4    填空题
# Name: 题型, dtype: object

# %%
## 查看部分列的数据
## 注意：当我们要进行多列访问的时候，必须使用二维列表作为参数
sheet1_data[["题型","题干"]].head()
# Out:
#     题型                      题干
# 0   单选        关于电商网站数据抓取的方式不包括
# 1  判断题   以下软件/语言是否都属于数据分析软件/语言
# 2   单选  在电商中针对仓储备货场景一般采用什么分析方式
# 3  填空题            数据分析的四大步骤是什么
# 4  填空题         优秀数据分析师的三个特点是什么

# %%
type(sheet1_data["题型"])
# Out:
# pandas.core.series.Series

# %%
df2 = pd.DataFrame({"aa":[1,2,3],
                    "bbb":[4,5,6]},
                   index=[101,102,103])
df2
# Out:
#      aa  bbb
# 101   1    4
# 102   2    5
# 103   3    6

# %%
df2[[True,False,True]]
# Out:
#      aa  bbb
# 101   1    4
# 103   3    6

# %%
## 请筛选出难度为2的所有题目
sheet1_data[sheet1_data['难度']==2].head()
# Out:
#       专业   题型  难度   对应知识点                      题干  \
# 3   数据分析  填空题   2  数据分析概念            数据分析的四大步骤是什么
# 4   数据分析  填空题   2  数据分析概念         优秀数据分析师的三个特点是什么
# 7   数据分析   多选   2  数据分析概念        数据分析报告对一线业务的帮助包含
# 12  数据分析   单选   2  数据分析概念  在电商中针对业绩预测场景一般采用什么分析方式
# 18  数据分析  单选题   2  数据分析概念     适合观察时间序列的数据可视化图表是什么
#
#                                    选项（如果有）                   答案
# 3                                      NaN  数据抓取→数据清洗→数据分析→业务决策
# 4                                      NaN       业务理解、工具使用、沟通表达
# 7   A.广告投放优化\nB.渠道管理优化\nC.人员管理优化\nD.用户管理优化              A、B、C、D
# 12            A.线性回归\nB.数学仿真\nC.逻辑回归\nD.分类                    A
# 18              A.柱状图\nB.折线图\nC.雷达图\nD.散点图                    B

# %%
sheet1_data[['难度','题干']].head()
# Out:
#    难度                      题干
# 0   1        关于电商网站数据抓取的方式不包括
# 1   1   以下软件/语言是否都属于数据分析软件/语言
# 2   1  在电商中针对仓储备货场景一般采用什么分析方式
# 3   2            数据分析的四大步骤是什么
# 4   2         优秀数据分析师的三个特点是什么

# %%
# 如何进行行数据的访问
## 跟我们之前访问列表的区别在于
# 1、使用loc函数
# 2、我们必须使用二维的列表作为参数
sheet1_data.loc[[1,2,3]]
# Out:
#      专业   题型  难度   对应知识点                      题干  \
# 1  数据分析  判断题   1  数据分析概念   以下软件/语言是否都属于数据分析软件/语言
# 2  数据分析   单选   1  数据分析概念  在电商中针对仓储备货场景一般采用什么分析方式
# 3  数据分析  填空题   2  数据分析概念            数据分析的四大步骤是什么
#
#                           选项（如果有）                   答案
# 1  A.SPSS\nB.Python\nC.Excel\nD.R                    是
# 2    A.线性回归\nB.数学仿真\nC.逻辑回归\nD.分类                    B
# 3                             NaN  数据抓取→数据清洗→数据分析→业务决策

# %%
## 我们如何进行行和列的同时访问
sheet1_data.loc[[1,2,3],["题干","题型"]]
# Out:
#                        题干   题型
# 1   以下软件/语言是否都属于数据分析软件/语言  判断题
# 2  在电商中针对仓储备货场景一般采用什么分析方式   单选
# 3            数据分析的四大步骤是什么  填空题

# %%
sheet1_data.loc[[1,2,3],"题干":]
# Out:
#                        题干                         选项（如果有）                   答案
# 1   以下软件/语言是否都属于数据分析软件/语言  A.SPSS\nB.Python\nC.Excel\nD.R                    是
# 2  在电商中针对仓储备货场景一般采用什么分析方式    A.线性回归\nB.数学仿真\nC.逻辑回归\nD.分类                    B
# 3            数据分析的四大步骤是什么                             NaN  数据抓取→数据清洗→数据分析→业务决策

# %%
## 行列访问的第二种方法 iloc
# 1、loc和iloc的区别
# - loc使用的是字段的名称进行访问
# - iloc使用的是索引数字进行访问

# %%
sheet1_data.head()
# Out:
#      专业   题型  难度   对应知识点                      题干  \
# 0  数据分析   单选   1  数据分析概念        关于电商网站数据抓取的方式不包括
# 1  数据分析  判断题   1  数据分析概念   以下软件/语言是否都属于数据分析软件/语言
# 2  数据分析   单选   1  数据分析概念  在电商中针对仓储备货场景一般采用什么分析方式
# 3  数据分析  填空题   2  数据分析概念            数据分析的四大步骤是什么
# 4  数据分析  填空题   2  数据分析概念         优秀数据分析师的三个特点是什么
#
#                                 选项（如果有）                   答案
# 0  A.第三方工具抓取\nB.爬虫程序抓取\nC.数据库提取\nD.人工抓取                    C
# 1        A.SPSS\nB.Python\nC.Excel\nD.R                    是
# 2          A.线性回归\nB.数学仿真\nC.逻辑回归\nD.分类                    B
# 3                                   NaN  数据抓取→数据清洗→数据分析→业务决策
# 4                                   NaN       业务理解、工具使用、沟通表达

# %%
sheet1_data.iloc[[0,1,2,3],[0,1,2]]
# Out:
#      专业   题型  难度
# 0  数据分析   单选   1
# 1  数据分析  判断题   1
# 2  数据分析   单选   1
# 3  数据分析  填空题   2

# %%
sheet1_data.iloc[[0,1,2,3],1:3]
# Out:
#     题型  难度
# 0   单选   1
# 1  判断题   1
# 2   单选   1
# 3  填空题   2

# %%
sheet1_data.iloc[1:5,1:3]
# Out:
#     题型  难度
# 1  判断题   1
# 2   单选   1
# 3  填空题   2
# 4  填空题   2

# %%
## 行列的访问第三种方式
sheet1_data["专业"][3]
# Out:
# '数据分析'

# %%
sheet1_data[['专业','题干']][3:6]
# Out:
#      专业                    题干
# 3  数据分析          数据分析的四大步骤是什么
# 4  数据分析       优秀数据分析师的三个特点是什么
# 5  数据分析  Excel相比于Python的优势是什么

# %%
sheet1_data.at[1,"题干"]
# Out:
# '以下软件/语言是否都属于数据分析软件/语言'

# %%
sheet1_data.loc[1,"题干"]
# Out:
# '以下软件/语言是否都属于数据分析软件/语言'

# %%
sheet1_data.iat[1,4]
# Out:
# '以下软件/语言是否都属于数据分析软件/语言'

# %%
sheet2_data.head()
# Out:
#      专业   题型  难度   对应知识点                         题干  \
# 0  数据分析  填空题   1  数据分析概念        互联网营销活动数据分析的基本模型是什么
# 1  数据分析  填空题   2  数据分析概念  对于多维度数据之间相关性判断一般使用哪种分析模型？
# 2  数据分析   多选   2  数据分析概念            使用数学仿真时需要包含哪些元素
# 3  数据分析  判断题   3  数据分析概念          数学仿真可以直接给出业务决策最优解
# 4  数据分析   多选   3  数据分析概念        多变量线性回归时确定重要变量的方法包含
#
#                       选项（如果有）              答案
# 0                         NaN  找出问题→分析问题→解决问题
# 1                         NaN           波士顿矩阵
# 2  A.平均数\nB.分布\nC.方差\nD.可视化图表         A、B、C、D
# 3                         NaN      错（仿真值只是参考）
# 4      A.向前选择\nB.向后选择\nC.混合选择           A、B、C

# %%
## 第三套题的读取
sheet3_data = pd.read_excel("数据分析测试题.xlsx",sheet_name = "第一阶段第三套")
sheet3_data
# Out:
#       专业   题型  难度            对应知识点  \
# 0   数据分析  单选题   1           业务逻辑概念
# 1   数据分析  判断题   1           业务逻辑概念
# 2   数据分析  判断题   1           业务逻辑概念
# 3   数据分析  单选题   1           业务逻辑概念
# 4   数据分析  填空题   3           业务逻辑概念
# 5   数据分析  判断题   2           业务逻辑概念
# 6   数据分析  判断题   2           业务逻辑概念
# 7   数据分析  多选题   2           业务逻辑概念
# 8   数据分析  判断题   2           业务逻辑概念
# 9   数据分析  判断题   2           业务逻辑概念
# 10  数据分析  填空题   3           业务逻辑概念
# 11  数据分析  多选题   3           业务逻辑概念
# 12  数据分析  判断题   2           业务逻辑概念
# 13  数据分析  判断题   2           业务逻辑概念
# 14  数据分析  填空题   3           业务逻辑概念
# 15  数据分析  单选题   2           业务逻辑概念
# 16  数据分析  判断题   3           业务逻辑概念
# 17  数据分析  多选题   2           业务逻辑概念
# 18  数据分析  判断题   2           业务逻辑概念
# 19  数据分析  多选题   3           业务逻辑概念
# 20  数据分析  填空题   1           业务逻辑概念
# 21  数据分析  判断题   1           业务逻辑概念
# 22  数据分析  判断题   3           业务逻辑概念
# 23  数据分析  判断题   2           业务逻辑概念
# 24  数据分析  判断题   2           业务逻辑概念
# ...

# %%
final_data = pd.concat([sheet1_data,sheet2_data,sheet3_data])
final_data
# Out:
#       专业   题型  难度      对应知识点                                        题干  \
# 0   数据分析   单选   1     数据分析概念                          关于电商网站数据抓取的方式不包括
# 1   数据分析  判断题   1     数据分析概念                     以下软件/语言是否都属于数据分析软件/语言
# 2   数据分析   单选   1     数据分析概念                    在电商中针对仓储备货场景一般采用什么分析方式
# 3   数据分析  填空题   2     数据分析概念                              数据分析的四大步骤是什么
# 4   数据分析  填空题   2     数据分析概念                           优秀数据分析师的三个特点是什么
# ..   ...  ...  ..        ...                                       ...
# 45  数据分析  单选题   1  NumPy数据运算   Series数据类型声明时，我们想要自定义其索引的值，可以对哪个参数进行设置？
# 46  数据分析  单选题   1  NumPy数据运算                         Pandas用什么来标记缺失数据？
# 47  数据分析  单选题   1  NumPy数据运算   在使用NumPy进行数据运算时，我们可以使用什么函数来直接计算元素的算数平方根
# 48  数据分析  单选题   1  NumPy数据运算     有NumPy对象arr，想要计算arr中各元素的4次方，下列代码正确的是？
# 49  数据分析  单选题   1  NumPy数据运算  有NumPy对象arr，想要计算arr中各元素以2为底的对数，下列代码正确的是？
#
#                                               选项（如果有）                   答案
# ...

# %%
# 统计每一列数据的总数
final_data.count()
# Out:
# 专业         150
# 题型         150
# 难度         150
# 对应知识点      150
# 题干         150
# 选项（如果有）     81
# 答案         147
# dtype: int64

# %%
# 查看数据详情
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 49
# Data columns (total 7 columns):
# 专业         150 non-null object
# 题型         150 non-null object
# 难度         150 non-null int64
# 对应知识点      150 non-null object
# 题干         150 non-null object
# 选项（如果有）    81 non-null object
# 答案         147 non-null object
# dtypes: int64(1), object(6)
# memory usage: 9.4+ KB

# %%
## 最后需要把最后的数据写入到新的excel文件中
final_data.to_excel("final_data.xlsx",sheet_name='第一阶段三套题')

# %%
## 你很有可能会遇到这样的一个问题
## ModuleNotFoundError: No module named openpyxl

#这种安装方式是在命令行中安装 pip install openpyxl
## 如果要在jupyter notebook中安装   !pip install openpyxl

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 20.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install --upgrade pip' command.

# %%
df3 = pd.DataFrame({
    "姓名":["建国","爱国","卫国","嘎子"],
    "年龄":[17,18,19,20] 
})
df3
# Out:
#    姓名  年龄
# 0  建国  17
# 1  爱国  18
# 2  卫国  19
# 3  嘎子  20

# %%
## 新增一行数据
df3.loc[4] = ["爱党",21]

# %%
df3
# Out:
#    姓名  年龄
# 0  建国  17
# 1  爱国  18
# 2  卫国  19
# 3  嘎子  20
# 4  爱党  21

# %%
## 新增一列数据
df3['是否入党']=["是","否","是","是","否"]

# %%
df3
# Out:
#    姓名  年龄 是否入党
# 0  建国  17    是
# 1  爱国  18    否
# 2  卫国  19    是
# 3  嘎子  20    是
# 4  爱党  21    否

# %%
# 更新数据
df3["年龄"]=[22,23,24,25,26]
df3
# Out:
#    姓名  年龄 是否入党
# 0  建国  22    是
# 1  爱国  23    否
# 2  卫国  24    是
# 3  嘎子  25    是
# 4  爱党  26    否

# %%
## 删除行操作, drop支持的行索引删除
# drop的删除并不作用在原数据上
ddf3 = df3.drop(0)

# %%
df3
# Out:
#    姓名  年龄 是否入党
# 0  建国  22    是
# 1  爱国  23    否
# 2  卫国  24    是
# 3  嘎子  25    是
# 4  爱党  26    否

# %%
ddf3
# Out:
#    姓名  年龄 是否入党
# 1  爱国  23    否
# 2  卫国  24    是
# 3  嘎子  25    是
# 4  爱党  26    否

# %%
## 使用drop删除，并且作用在原数据上
df3.drop(1,inplace=True)

# %%
df3
# Out:
#    姓名  年龄 是否入党
# 0  建国  22    是
# 2  卫国  24    是
# 3  嘎子  25    是
# 4  爱党  26    否

# %%
## 删除列
df3.drop(["年龄"], axis=1)
# Out:
#    姓名 是否入党
# 0  建国    是
# 2  卫国    是
# 3  嘎子    是
# 4  爱党    否

# %%
df3
# Out:
#    姓名  年龄 是否入党
# 0  建国  22    是
# 2  卫国  24    是
# 3  嘎子  25    是
# 4  爱党  26    否

# %%
## 删除列,并作用在原数据上
df3.drop(["年龄"], axis=1,inplace=True)

# %%
df3
# Out:
#    姓名 是否入党
# 0  建国    是
# 2  卫国    是
# 3  嘎子    是
# 4  爱党    否
